# %%
#instalando pytorch
#!pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# %%
#clonando repositorio
#!git clone https://github.com/ultralytics/yolov5
#cd yolov5
#pip install -r requirements.txt

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
#https://pytorch.org/hub/ultralytics_yolov5/ aca puedes ver cuales modelos ocupar s(small)
model=torch.hub.load('ultralytics/yolov5','yolov5s')
# Out:
# Using cache found in /home/jair/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-12-6 Python-3.11.5 torch-2.1.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3090 Ti, 24214MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
#ruta a una imagen
img='http://implansaltillo.mx/img_articulos_revista/articulo_40.jpg'
#pasar imagen por la red
results=model(img)
#mostar resultados en texto 
results.print()
# Out:
# image 1/1: 720x1280 17 persons, 11 cars, 2 buss, 2 trucks, 1 backpack, 1 potted plant
# Speed: 966.0ms pre-process, 161.9ms inference, 139.6ms NMS per image at shape (1, 3, 384, 640)

# %%
#visualizacion grafica de resultados
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
#usar red para  desde webcam
cap = cv2.VideoCapture(1)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
